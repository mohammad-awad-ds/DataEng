# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn 
import psycopg2 
from sqlalchemy import create_engine
import time

# %%
import pandas as pd 

Day='01-01-2022'
URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
DF_day=pd.read_csv(URL_Day)
DF_day['Day']=Day
cond=(DF_day.Country_Region=='United Kingdom')#&(DF_day.Province_State=='England')
Selec_columns=['Day','Country_Region', 'Last_Update',
       'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
       'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio','Province_State']
DF_i=DF_day[cond][Selec_columns].reset_index(drop=True)
DF_i.head(4)
# Out:
#           Day  Country_Region          Last_Update      Lat    Long_  \
# 0  01-01-2022  United Kingdom  2022-01-02 04:20:52  18.2206 -63.0686
# 1  01-01-2022  United Kingdom  2022-01-02 04:20:52  32.3078 -64.7505
# 2  01-01-2022  United Kingdom  2022-01-02 04:20:52  18.4207 -64.6400
# 3  01-01-2022  United Kingdom  2022-01-02 04:20:52  19.3133 -81.2546
#
#    Confirmed  Deaths  Recovered  Active  \
# 0       1674       5        NaN     NaN
# 1       6420     110        NaN     NaN
# 2       3492      39        NaN     NaN
# 3       8943      12        NaN     NaN
#
#                              Combined_Key  Incident_Rate  Case_Fatality_Ratio  \
# 0                Anguilla, United Kingdom   11158.512198             0.298686
# 1                 Bermuda, United Kingdom   10309.443900             1.713396
# 2  British Virgin Islands, United Kingdom   11548.764758             1.116838
# 3          Cayman Islands, United Kingdom   13607.729763             0.134183
#
#            Province_State
# 0                Anguilla
# 1                 Bermuda
# 2  British Virgin Islands
# 3          Cayman Islands

# %%
DF_i.groupby(['Province_State']).count()
# Out:
#                                               Day  Country_Region  \
# Province_State
# Anguilla                                        1               1
# Bermuda                                         1               1
# British Virgin Islands                          1               1
# Cayman Islands                                  1               1
# Channel Islands                                 1               1
# England                                         1               1
# Falkland Islands (Malvinas)                     1               1
# Gibraltar                                       1               1
# Guernsey                                        1               1
# Isle of Man                                     1               1
# Jersey                                          1               1
# Montserrat                                      1               1
# Northern Ireland                                1               1
# Saint Helena, Ascension and Tristan da Cunha    1               1
# Scotland                                        1               1
# Turks and Caicos Islands                        1               1
# Unknown                                         1               1
# Wales                                           1               1
#
#                                               Last_Update  Lat  Long_  \
# Province_State
# Anguilla                                                1    1      1
# Bermuda                                                 1    1      1
# British Virgin Islands                                  1    1      1
# Cayman Islands                                          1    1      1
# Channel Islands                                         1    1      1
# England                                                 1    1      1
# Falkland Islands (Malvinas)                             1    1      1
# Gibraltar                                               1    1      1
# Guernsey                                                1    1      1
# Isle of Man                                             1    1      1
# Jersey                                                  1    1      1
# Montserrat                                              1    1      1
# Northern Ireland                                        1    1      1
# Saint Helena, Ascension and Tristan da Cunha            1    1      1
# Scotland                                                1    1      1
# Turks and Caicos Islands                                1    1      1
# Unknown                                                 1    0      0
# Wales                                                   1    1      1
#
#                                               Confirmed  Deaths  Recovered  \
# Province_State
# Anguilla                                              1       1          0
# Bermuda                                               1       1          0
# British Virgin Islands                                1       1          0
# Cayman Islands                                        1       1          0
# Channel Islands                                       1       1          0
# England                                               1       1          0
# Falkland Islands (Malvinas)                           1       1          0
# Gibraltar                                             1       1          0
# Guernsey                                              1       1          1
# Isle of Man                                           1       1          0
# Jersey                                                1       1          1
# Montserrat                                            1       1          0
# Northern Ireland                                      1       1          0
# Saint Helena, Ascension and Tristan da Cunha          1       1          0
# Scotland                                              1       1          0
# Turks and Caicos Islands                              1       1          0
# Unknown                                               1       1          0
# Wales                                                 1       1          0
#
#                                               Active  Combined_Key  \
# Province_State
# Anguilla                                           0             1
# Bermuda                                            0             1
# British Virgin Islands                             0             1
# Cayman Islands                                     0             1
# Channel Islands                                    0             1
# England                                            0             1
# Falkland Islands (Malvinas)                        0             1
# Gibraltar                                          0             1
# Guernsey                                           1             1
# Isle of Man                                        0             1
# Jersey                                             1             1
# Montserrat                                         0             1
# Northern Ireland                                   0             1
# Saint Helena, Ascension and Tristan da Cunha       0             1
# Scotland                                           0             1
# Turks and Caicos Islands                           0             1
# Unknown                                            0             1
# Wales                                              0             1
#
#                                               Incident_Rate  \
# Province_State
# Anguilla                                                  1
# Bermuda                                                   1
# British Virgin Islands                                    1
# Cayman Islands                                            1
# Channel Islands                                           1
# England                                                   1
# Falkland Islands (Malvinas)                               1
# Gibraltar                                                 1
# Guernsey                                                  1
# Isle of Man                                               1
# Jersey                                                    1
# Montserrat                                                1
# Northern Ireland                                          1
# Saint Helena, Ascension and Tristan da Cunha              1
# Scotland                                                  1
# Turks and Caicos Islands                                  1
# Unknown                                                   0
# Wales                                                     1
#
#                                               Case_Fatality_Ratio
# Province_State
# Anguilla                                                        1
# Bermuda                                                         1
# British Virgin Islands                                          1
# Cayman Islands                                                  1
# Channel Islands                                                 1
# England                                                         1
# Falkland Islands (Malvinas)                                     1
# Gibraltar                                                       1
# Guernsey                                                        1
# Isle of Man                                                     1
# Jersey                                                          1
# Montserrat                                                      1
# Northern Ireland                                                1
# Saint Helena, Ascension and Tristan da Cunha                    1
# Scotland                                                        1
# Turks and Caicos Islands                                        1
# Unknown                                                         0
# Wales                                                           1

# %%
def get_list_of_days():
    List_of_days=[]
    for year in range(2020,2022):
        for month in range(1,13):
            for day in range(1,32):
                month=int(month)
                if day <=9:
                    day=f'0{day}'

                if month <= 9 :
                    month=f'0{month}'
                List_of_days.append(f'{month}-{day}-{year}')
    return List_of_days

def get_df_uk_daily(Day):
    DF_i=None
    try: 
        URL_Day=f'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/{Day}.csv'
        DF_day=pd.read_csv(URL_Day)
        DF_day['Day']=Day
        cond=(DF_day.Country_Region=='United Kingdom')#&(DF_day.Province_State=='England')
        Selec_columns=['Day','Country_Region', 'Last_Update',
              'Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active',
              'Combined_Key', 'Incident_Rate', 'Case_Fatality_Ratio']
        DF_i=DF_day[cond][Selec_columns].reset_index(drop=True)
    except:
        #print(f'{Day} is not available!')
        pass
    return DF_i

def get_files_uk(List_of_days):
    Start=time.time()
    df_all=[]
    for Day in List_of_days:
        df_all.append(get_df_uk_daily(Day))
    End=time.time()
    Time_in_sec=round((End-Start)/60,2)
    print(f'It took {Time_in_sec} minutes to get all data')

    df_uk=pd.concat(df_all).reset_index(drop=True)
    # Create DateTime for Last_Update
    df_uk['Last_Update']=pd.to_datetime(df_uk.Last_Update, infer_datetime_format=True)  
    df_uk['Day']=pd.to_datetime(df_uk.Day, infer_datetime_format=True)  

    df_uk['Case_Fatality_Ratio']=df_uk['Case_Fatality_Ratio'].astype(float)

    df_uk.head(10)
    return df_uk.copy()

# %%
list_of_days = get_list_of_days()
print(list_of_days[:10])
# Out:
# ['01-01-2020', '01-02-2020', '01-03-2020', '01-04-2020', '01-05-2020', '01-06-2020', '01-07-2020', '01-08-2020', '01-09-2020', '01-10-2020']

# %%
df_uk = get_files_uk(list_of_days)
# Out:
# It took 2.98 minutes to get all data

# %%
selected_columns = ['Confirmed','Deaths', 'Recovered', 'Active', 'Incident_Rate','Case_Fatality_Ratio']
df_uk_notscaled = df_uk[selected_columns]

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler()

df_uk_scaled = pd.DataFrame(min_max_scaler.fit_transform(df_uk[selected_columns]),columns=selected_columns)
df_uk_scaled['Day']=df_uk.Day
df_uk_scaled.index=df_uk.Day
df_uk_scaled.head(3)
# Out:
#                Confirmed    Deaths  Recovered    Active  Incident_Rate  \
# Day
# 2020-11-09  2.730040e-07  0.000000   0.000360  0.000000       0.000774
# 2020-11-09  1.947428e-05  0.000070   0.021870  0.000005       0.013306
# 2020-11-09  6.461094e-06  0.000008   0.008411  0.000000       0.009092
#
#             Case_Fatality_Ratio        Day
# Day
# 2020-11-09             0.000000 2020-11-09
# 2020-11-09             0.546729 2020-11-09
# 2020-11-09             0.183099 2020-11-09

# %%
df_uk_scaled[selected_columns].plot(figsize=(20,10))
plt.savefig('output/uk_scoring_report.png')

# %%
df_uk_scaled.to_csv('output/uk_scoring_report.csv')
df_uk_notscaled.to_csv('output/uk_scoring_report_NotScaled.csv')

# %%
host="postgres" 
database="deproject"
user="admin"
password="admin"
port='5432'
engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
print(engine.table_names())


df_uk_scaled.to_sql('uk_scoring_report', engine,if_exists='replace',index=False)
